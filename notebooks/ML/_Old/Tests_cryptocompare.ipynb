# %%
import pandas.io.sql as psql
import pandas as pd
from datetime import datetime, timedelta, date
from sqlalchemy import create_engine, TIMESTAMP
import pytz
import time, requests, json

api_key = '1f63b31234c8dede60b0ff7ac2edef29774893b738ab58da8c94f6e81b0e827d'
url = 'https://min-api.cryptocompare.com/data/all/coinlist'



# get response in  from url
def get_dataframe_from_response(url):
    df = pd.DataFrame()
#     headers = {
#      'Accept': 'application/json',
#      'Accept-Encoding': 'deflate, gzip',
#      'X-CMC_PRO_API_KEY': api_key,
#     }
    headers = {
        "authorization": "Apikey " + api_key
    }
    r = requests.get(url, headers=headers)
    if r.status_code == 200:
        response = json.loads(r.text)
        df = pd.DataFrame(response['Data'])
    else:
        toto = 0 # error
    return df

get_dataframe_from_response(url)
# Out:
#                                           42  \
# Algorithm                             Scrypt
# BlockNumber                                0
# BlockReward                                0
# BlockTime                                  0
# BuiltOn                                  N/A
# CoinName                             42 Coin
# FullName                        42 Coin (42)
# FullyPremined                              0
# Id                                      4321
# ImageUrl              /media/12318415/42.png
# IsTrading                               True
# Name                                      42
# NetHashesPerSecond                         0
# PreMinedValue                            N/A
# ProofType                            PoW/PoS
# SmartContractAddress                     N/A
# SortOrder                                 34
# Sponsored                              False
# Symbol                                    42
# TotalCoinSupply                           42
# TotalCoinsFreeFloat                      N/A
# TotalCoinsMined                           42
# Url                       /coins/42/overview
#
#                                                              300  \
# Algorithm                                                    N/A
# BlockNumber                                                    0
# BlockReward                                                    0
# BlockTime                                                      0
# BuiltOn                                                     7605
# CoinName                                               300 token
# FullName                                         300 token (300)
# FullyPremined                                                  0
# Id                                                        749869
# ImageUrl                                 /media/27010595/300.png
# IsTrading                                                   True
# Name                                                         300
# NetHashesPerSecond                                             0
# PreMinedValue                                                N/A
# ProofType                                                    N/A
# SmartContractAddress  0xaec98a708810414878c3bcdf46aad31ded4a4557
# SortOrder                                                   2212
# Sponsored                                                  False
# Symbol                                                       300
# TotalCoinSupply                                              300
# TotalCoinsFreeFloat                                          N/A
# TotalCoinsMined                                              300
# Url                                          /coins/300/overview
#
#                                         365                    404  \
# Algorithm                               X11                 Scrypt
# BlockNumber                             NaN                    NaN
# BlockReward                             NaN                    NaN
# BlockTime                               NaN                    NaN
# BuiltOn                                 N/A                    N/A
# CoinName                            365Coin                404Coin
# FullName                      365Coin (365)          404Coin (404)
# FullyPremined                             0                      0
# Id                                    33639                  21227
# ImageUrl              /media/352070/365.png  /media/351001/404.png
# IsTrading                              True                   True
# Name                                    365                    404
# NetHashesPerSecond                      NaN                    NaN
# PreMinedValue                           N/A                    N/A
# ProofType                           PoW/PoS                PoW/PoS
# SmartContractAddress                    N/A                    N/A
# SortOrder                               916                    602
# Sponsored                             False                  False
# Symbol                                  365                    404
# TotalCoinSupply                  2300000000              532000000
# TotalCoinsFreeFloat                     N/A                    N/A
# TotalCoinsMined                         NaN                    NaN
# Url                     /coins/365/overview    /coins/404/overview
#
#                                           433                    611  \
# Algorithm                                 N/A                 SHA256
# BlockNumber                               NaN                    NaN
# BlockReward                               NaN                    NaN
# BlockTime                                 NaN                    NaN
# BuiltOn                                  7605                    N/A
# CoinName                            433 Token              SixEleven
# FullName                      433 Token (433)        SixEleven (611)
# FullyPremined                               0                      0
# Id                                     926547                  20909
# ImageUrl              /media/34836095/433.png  /media/350985/611.png
# IsTrading                               False                   True
# Name                                      433                    611
# NetHashesPerSecond                        NaN                    NaN
# PreMinedValue                             N/A                    N/A
# ProofType                                 N/A                    PoW
# SmartContractAddress                      N/A                    N/A
# SortOrder                                3505                    586
# Sponsored                               False                  False
# Symbol                                    433                    611
# TotalCoinSupply                    1000000000                 611000
# TotalCoinsFreeFloat                       N/A                    N/A
# TotalCoinsMined                           NaN                    NaN
# Url                       /coins/433/overview    /coins/611/overview
#
#                                         808                    888  \
# Algorithm                            SHA256                    N/A
# BlockNumber                          435028                      0
# BlockReward                          985944                      0
# BlockTime                                 0                     88
# BuiltOn                                 N/A                    N/A
# CoinName                                808               Octocoin
# FullName                          808 (808)         Octocoin (888)
# FullyPremined                             0                      0
# Id                                    28223                  29462
# ImageUrl              /media/351513/808.png  /media/351639/888.png
# IsTrading                              True                   True
# Name                                    808                    888
# NetHashesPerSecond                        0                      0
# PreMinedValue                           N/A                    N/A
# ProofType                           PoW/PoS                    PoW
# SmartContractAddress                    N/A                    N/A
# SortOrder                               750                    811
# Sponsored                             False                  False
# Symbol                                  808                    888
# TotalCoinSupply                         N/A              135776563
# TotalCoinsFreeFloat                     N/A                    N/A
# TotalCoinsMined                 2.05526e+10               50786536
# Url                     /coins/808/overview    /coins/888/overview
#
#                                         1337                   2015  \
# Algorithm                                X13                    X11
# BlockNumber                                0                    NaN
# BlockReward                                0                    NaN
# BlockTime                                 60                    NaN
# BuiltOn                                  N/A                    N/A
# CoinName                                1337              2015 coin
# FullName                         1337 (1337)       2015 coin (2015)
# FullyPremined                              0                      0
# Id                                     20824                   3744
# ImageUrl              /media/350976/1337.png  /media/20180/2015.png
# IsTrading                               True                   True
# Name                                    1337                   2015
# NetHashesPerSecond                         0                    NaN
# PreMinedValue                            N/A                    N/A
# ProofType                            PoW/PoS                PoW/PoS
# SmartContractAddress                     N/A                    N/A
# SortOrder                                577                     33
# Sponsored                              False                  False
# Symbol                                  1337                   2015
# TotalCoinSupply                 314159265359                      0
# TotalCoinsFreeFloat                      N/A                    N/A
# TotalCoinsMined                  2.91434e+10                    NaN
# Url                     /coins/1337/overview   /coins/2015/overview
#
#                                          ...                      \
# Algorithm                                ...
# BlockNumber                              ...
# BlockReward                              ...
# BlockTime                                ...
# BuiltOn                                  ...
# CoinName                                 ...
# FullName                                 ...
# FullyPremined                            ...
# Id                                       ...
# ImageUrl                                 ...
# IsTrading                                ...
# Name                                     ...
# NetHashesPerSecond                       ...
# PreMinedValue                            ...
# ProofType                                ...
# SmartContractAddress                     ...
# SortOrder                                ...
# Sponsored                                ...
# Symbol                                   ...
# TotalCoinSupply                          ...
# TotalCoinsFreeFloat                      ...
# TotalCoinsMined                          ...
# Url                                      ...
#
#                                           VIDY                      SUNEX  \
# Algorithm                                  N/A                        N/A
# BlockNumber                                NaN                        NaN
# BlockReward                                NaN                        NaN
# BlockTime                                  NaN                        NaN
# BuiltOn                                   7605                       7605
# CoinName                                  Vidy           The Sun Exchange
# FullName                           Vidy (VIDY)   The Sun Exchange (SUNEX)
# FullyPremined                                0                          0
# Id                                      928450                     928449
# ImageUrl              /media/35309399/vidy.png  /media/35309400/sunex.jpg
# IsTrading                                False                      False
# Name                                      VIDY                      SUNEX
# NetHashesPerSecond                         NaN                        NaN
# PreMinedValue                              N/A                        N/A
# ProofType                                  N/A                        N/A
# SmartContractAddress                       N/A                        N/A
# SortOrder                                 3858                       3857
# Sponsored                                False                      False
# Symbol                                    VIDY                      SUNEX
# TotalCoinSupply                    10000000000                  332000000
# TotalCoinsFreeFloat                        N/A                        N/A
# TotalCoinsMined                            NaN                        NaN
# Url                       /coins/vidy/overview      /coins/sunex/overview
#
#                                           XRBT                      ALUX  \
# Algorithm                                  N/A                       N/A
# BlockNumber                                NaN                       NaN
# BlockReward                                NaN                       NaN
# BlockTime                                  NaN                       NaN
# BuiltOn                                   7605                      7605
# CoinName                                Xtribe                 Alux Bank
# FullName                         Xtribe (XRBT)          Alux Bank (ALUX)
# FullyPremined                                0                         0
# Id                                      928452                    928455
# ImageUrl              /media/35309401/xrbt.png  /media/35309403/alux.png
# IsTrading                                False                     False
# Name                                      XRBT                      ALUX
# NetHashesPerSecond                         NaN                       NaN
# PreMinedValue                              N/A                       N/A
# ProofType                                  N/A                       N/A
# SmartContractAddress                       N/A                       N/A
# SortOrder                                 3859                      3860
# Sponsored                                False                     False
# Symbol                                    XRBT                      ALUX
# TotalCoinSupply                     2000000000                1000000000
# TotalCoinsFreeFloat                        N/A                       N/A
# TotalCoinsMined                            NaN                       NaN
# Url                       /coins/xrbt/overview      /coins/alux/overview
#
#                                                            XBOND  \
# Algorithm                                                    N/A
# BlockNumber                                                    0
# BlockReward                                                    0
# BlockTime                                                      0
# BuiltOn                                                     7605
# CoinName                                                Bitacium
# FullName                                        Bitacium (XBOND)
# FullyPremined                                                  0
# Id                                                        928459
# ImageUrl                               /media/35309402/xbond.png
# IsTrading                                                  False
# Name                                                       XBOND
# NetHashesPerSecond                                             0
# PreMinedValue                                                N/A
# ProofType                                                    N/A
# SmartContractAddress  0x19d6c93f2d298362045d63c6e32f741954379a6f
# SortOrder                                                   3861
# Sponsored                                                  False
# Symbol                                                     XBOND
# TotalCoinSupply                                         25000000
# TotalCoinsFreeFloat                                          N/A
# TotalCoinsMined                                         25000000
# Url                                        /coins/xbond/overview
#
#                                                             BOSE  \
# Algorithm                                                    N/A
# BlockNumber                                                    0
# BlockReward                                                    0
# BlockTime                                                      0
# BuiltOn                                                     7605
# CoinName                                                 Bitbose
# FullName                                          Bitbose (BOSE)
# FullyPremined                                                  0
# Id                                                        928465
# ImageUrl                                /media/35309407/bose.png
# IsTrading                                                  False
# Name                                                        BOSE
# NetHashesPerSecond                                             0
# PreMinedValue                                                N/A
# ProofType                                                    N/A
# SmartContractAddress  0xcde6050497608585ea0ab85cb3a546d0d3bbd63d
# SortOrder                                                   3862
# Sponsored                                                  False
# Symbol                                                      BOSE
# TotalCoinSupply                                        300000000
# TotalCoinsFreeFloat                                          N/A
# TotalCoinsMined                                        300000000
# Url                                         /coins/bose/overview
#
#                                           BIS  \
# Algorithm                                 N/A
# BlockNumber                                 0
# BlockReward                                 0
# BlockTime                                  60
# BuiltOn                                   N/A
# CoinName                              Bismuth
# FullName                        Bismuth (BIS)
# FullyPremined                               0
# Id                                     322963
# ImageUrl              /media/35309411/bis.png
# IsTrading                                True
# Name                                      BIS
# NetHashesPerSecond                          0
# PreMinedValue                             N/A
# ProofType                                 PoW
# SmartContractAddress                      N/A
# SortOrder                                1638
# Sponsored                               False
# Symbol                                    BIS
# TotalCoinSupply                     109999978
# TotalCoinsFreeFloat                       N/A
# TotalCoinsMined                   1.57591e+07
# Url                       /coins/bis/overview
#
#                                                              DMT  \
# Algorithm                                                    N/A
# BlockNumber                                                    0
# BlockReward                                                    0
# BlockTime                                                      0
# BuiltOn                                                     7605
# CoinName                                                 DMarket
# FullName                                           DMarket (DMT)
# FullyPremined                                                  0
# Id                                                        192400
# ImageUrl                              /media/1383841/dmarket.png
# IsTrading                                                   True
# Name                                                         DMT
# NetHashesPerSecond                                             0
# PreMinedValue                                                N/A
# ProofType                                                    N/A
# SmartContractAddress  0x2ccbff3a042c68716ed2a2cb0c544a9f1d1935e1
# SortOrder                                                   1381
# Sponsored                                                  False
# Symbol                                                       DMT
# TotalCoinSupply                                 56921773.1719715
# TotalCoinsFreeFloat                                          N/A
# TotalCoinsMined                                      5.69218e+07
# Url                                          /coins/dmt/overview
#
#                                                              THO  \
# Algorithm                                                    N/A
# BlockNumber                                                    0
# BlockReward                                                    0
# BlockTime                                                      0
# BuiltOn                                                     7605
# CoinName                                                  Athero
# FullName                                            Athero (THO)
# FullyPremined                                                  0
# Id                                                        928423
# ImageUrl                                 /media/35309386/tho.png
# IsTrading                                                  False
# Name                                                         THO
# NetHashesPerSecond                                             0
# PreMinedValue                                                N/A
# ProofType                                                    N/A
# SmartContractAddress  0x64fa5d4fafa693d4b9f4e16fbdd1ac0e30b048b2
# SortOrder                                                   3852
# Sponsored                                                  False
# Symbol                                                       THO
# TotalCoinSupply                                       2000000000
# TotalCoinsFreeFloat                                          N/A
# TotalCoinsMined                                       2000000000
# Url                                          /coins/tho/overview
#
#                                                              IPT
# Algorithm                                                    N/A
# BlockNumber                                                    0
# BlockReward                                                    0
# BlockTime                                                      0
# BuiltOn                                                    60963
# CoinName                                                Crypt-ON
# FullName                                          Crypt-ON (IPT)
# FullyPremined                                                  0
# Id                                                        927378
# ImageUrl                             /media/35284413/crypton.png
# IsTrading                                                  False
# Name                                                         IPT
# NetHashesPerSecond                                             0
# PreMinedValue                                                N/A
# ProofType                                                    N/A
# SmartContractAddress  0xd2a4069a479a988219bfa069ba4ed18b032dfd09
# SortOrder                                                   3672
# Sponsored                                                  False
# Symbol                                                       IPT
# TotalCoinSupply                            2647.4346337479949939
# TotalCoinsFreeFloat                                          N/A
# TotalCoinsMined                                          2647.43
# Url                                          /coins/ipt/overview
#
# [23 rows x 3566 columns]
