# %%
import pandas.io.sql as psql
import pandas as pd
from datetime import datetime, timedelta, date
from sqlalchemy import create_engine

# TODO : Replace with info from config file
#connection = create_engine('postgresql://dbuser:algocryptos@localhost:5432/algocryptos')
#connection2 = create_engine('postgresql://dbuser:algocryptos@localhost:9091/algocryptos')
connection = create_engine('postgresql://dbuser:algocryptos@localhost:9091/algocryptos')


# get data with query
squery = 'select * from coins'

df = psql.read_sql_query(squery, connection)

# %%
df
# Out:
#      id_cryptocompare crypto_name symbol  \
# 0                1183         NXT    NXT
# 1                2349         PPC    PPC
# 2                4403         BTM    BTM
# 3                4573         NEC    NEC
# 4                4592         RDD    RDD
# 5                4618         SYS    SYS
# 6                5280         BCN    BCN
# 7                5293        MAID   MAID
# 8                5296        MONA   MONA
# 9                6103         NXS    NXS
# 10              13070         GRS    GRS
# 11              13280         FCT    FCT
# 12              15876         EMC    EMC
# 13              16713         DCR    DCR
# 14              17778         REP    REP
# 15              18907         DGD    DGD
# 16              20333       STEEM  STEEM
# 17              24294       STRAT  STRAT
# 18              25921         ICN    ICN
# 19              30173        ARDR   ARDR
# 20              35953         XNG    XNG
# 21              45260         PAY    PAY
# 22             116384         BOS    BOS
# 23             136211        VERI   VERI
# 24             137013         SNT    SNT
# 25             141331        DENT   DENT
# 26             166390         XTZ    XTZ
# 27             177918         KIN    KIN
# 28             179896         PPT    PPT
# 29             186875       STORM  STORM
# ..                ...         ...    ...
# 132            716725         ZIL    ZIL
# 133             42433        PIVX   PIVX
# 134            917211         MFT    MFT
# 135            112392        QTUM   QTUM
# 136            517477         GTO    GTO
# 137            309621        LINK   LINK
# 138            190978          AE     AE
# 139             19745         LSK    LSK
# 140            107672         BAT    BAT
# 141            324068         ICX    ICX
# 142            431235        AION   AION
# 143             61877         RLC    RLC
# 144            925939         PAX    PAX
# 145            439963         CMT    CMT
# 146            877073        NEXO   NEXO
# 147            925809        USDC   USDC
# 148             27368         NEO    NEO
# 149             27634         EDR    EDR
# 150             28081        FSN*   FSN*
# 151             30022         XZC    XZC
# 152             32699         ARK    ARK
# 153             41192         MKR    MKR
# 154            236131         VET    VET
# 155            213532         GAS    GAS
# 156            240142         WAN    WAN
# 157            310497         KNC    KNC
# 158            321992         ADA    ADA
# 159            409492         BCD    BCD
# 160            714255         OCN    OCN
# 161            808414         ONT    ONT
#
#                                 coin_name total_coin_supply  sort_order  \
# 0                                     Nxt        1000000000           6
# 1                                PeerCoin               N/A          14
# 2                                 BitMark          27580000          73
# 3                                 NeoCoin          80000000         169
# 4                                Reddcoin       27500000000         188
# 5                                 SysCoin         888000000         212
# 6                                ByteCoin      184467440735         249
# 7                           MaidSafe Coin         452552412         262
# 8                                MonaCoin         105120000         265
# 9                                   Nexus          78000000         390
# 10                           Groestlcoin          105000000         472
# 11                               Factoids           8753873         475
# 12                               Emercoin        1000000000         484
# 13                                 Decred          21000000         492
# 14                                  Augur          11000000         498
# 15                              Digix DAO           1999421         503
# 16                                  Steem          99692126         526
# 17                                Stratis               N/A         687
# 18                                Iconomi         100000000         710
# 19                                  Ardor        1000000000         842
# 20                                 Enigma           5000000         977
# 21                                   TenX    205218255.9485        1098
# 22                                BOScoin         500000000        1245
# 23                             Veritaseum         100000000        1260
# 24                   Status Network Token        6804870175        1264
# 25                                   Dent      100000000000        1268
# 26                                  Tezos               N/A        1273
# 27                                    Kin    10000000000000        1300
# 28                               Populous          53252246        1311
# 29                                  Storm      10000000000         1357
# ..                                    ...               ...         ...
# 132                               Zilliqa       12600000000        2152
# 133  Private Instant Verified Transaction               N/A        1051
# 134                             Mainframe      10000000000         3006
# 135                                  QTUM         100000000        1242
# 136                                 GIFTO        1000000000        1975
# 137                             ChainLink       1000000000         1591
# 138                             Aeternity         273685831        1375
# 139                                  Lisk         159918400         506
# 140                 Basic Attention Token        1500000000        1238
# 141                          ICON Project         400230000        1642
# 142                                  Aion      465934586.66        1925
# 143                                iEx.ec          87000000        1171
# 144                        Paxos Standard        15584134.8        3409
# 145                            CyberMiles        1000000000        1938
# 146                                  NEXO        1000000000        2686
# 147                              USD Coin                 0        3382
# 148                                   NEO         100000000         718
# 149                          E-Dinar Coin   999000000000000         722
# 150                                Fusion           3000000         732
# 151                                 ZCoin          21400000         832
# 152                                   ARK         125000000         885
# 153                                 Maker           1000000        1032
# 154                               Vechain       86712634466        1509
# 155                                   Gas           9677664        1445
# 156                              Wanchain               N/A        1519
# 157                         Kyber Network         226000000        1595
# 158                               Cardano       45000000000        1635
# 159                       Bitcoin Diamond         210000000        1895
# 160                               Odyssey       10000000000        2141
# 161                              Ontology        1000000000        2446
#
#     proof_type    algorithm                       image_url
# 0     PoS/LPoS          PoS            /media/20627/nxt.png
# 1          N/A          N/A  /media/19864/peercoin-logo.png
# 2          PoW       Scrypt            /media/20084/btm.png
# 3      PoW/PoS       Scrypt            /media/19824/nec.png
# 4      PoW/PoS       Scrypt            /media/19887/rdd.png
# 5          PoW       SHA256         /media/25792583/sys.png
# 6          PoW  CryptoNight         /media/12318404/bcn.png
# 7          N/A          N/A          /media/352247/maid.png
# 8          PoW       Scrypt           /media/19801/mona.png
# 9     PoW/nPoS         SHA3        /media/1382387/nexus.jpg
# 10         PoW      Groestl         /media/20780736/grs.png
# 11         N/A          N/A         /media/1382863/fct1.png
# 12     PoW/PoS       SHA256           /media/350611/emc.png
# 13     PoW/PoS     BLAKE256       /media/1382607/decred.png
# 14         N/A          N/A    /media/350815/augur-logo.png
# 15         N/A          N/A           /media/350851/dgd.png
# 16         PoW          N/A         /media/350907/steem.png
# 17     PoW/PoS          X13  /media/351303/stratis-logo.png
# 18         N/A          N/A           /media/351400/icn.png
# 19         PoS          N/A          /media/351736/ardr.png
# 20     PoW/PoS          X11           /media/352311/xng.png
# 21         N/A          N/A          /media/1383687/pay.png
# 22        mFBA          N/A          /media/1383521/bos.png
# 23         N/A          N/A         /media/1383562/veri.png
# 24         N/A          N/A          /media/1383568/snt.png
# 25         N/A          N/A         /media/1383613/dent.png
# 26        DPoS          N/A          /media/1383651/xbt.png
# 27         N/A          N/A          /media/1383731/kin.png
# 28         N/A          N/A          /media/1383747/ppt.png
# 29         N/A          N/A        /media/1383803/storm.jpg
# ..         ...          ...                             ...
# 132        N/A          N/A         /media/27010464/zil.png
# 133    PoW/PoS        Quark         /media/1382389/pivx.png
# 134        N/A          N/A         /media/34333427/mft.jpg
# 135        PoS      POS 3.0         /media/1383382/qtum.png
# 136        N/A          N/A         /media/16746671/gto.png
# 137        N/A          N/A        /media/12318078/link.png
# 138    PoW/PoS          N/A           /media/1383836/ae.png
# 139       DPoS         DPoS         /media/27011060/lsk.png
# 140        N/A          N/A          /media/1383370/bat.png
# 141        LFT          N/A         /media/12318192/icx.png
# 142        N/A          N/A        /media/16746538/aion.png
# 143        N/A          N/A         /media/12318418/rlc.png
# 144        N/A          N/A         /media/34835691/pax.png
# 145        N/A          N/A         /media/30002257/cmt.png
# 146        N/A          N/A        /media/32655865/nexo.jpg
# 147        N/A          N/A        /media/34835941/usdc.png
# 148        N/A          N/A          /media/1383858/neo.jpg
# 149       DPoS          X11           /media/351430/edc.png
# 150        PoW       SHA256           /media/351495/fsn.png
# 151        PoW       Lyra2Z         /media/1382780/xzc1.png
# 152       DPoS         DPoS           /media/351931/ark.png
# 153        N/A          N/A          /media/1382296/mkr.png
# 154        N/A          N/A         /media/12318129/ven.png
# 155        N/A          N/A          /media/1383858/neo.jpg
# 156        PoS          N/A          /media/9350742/wan.jpg
# 157        N/A          N/A         /media/12318084/knc.png
# 158        PoS    Ouroboros         /media/12318177/ada.png
# 159    PoW/PoS          X13         /media/16404872/bcd.png
# 160        N/A          N/A         /media/27010448/ocn.png
# 161        PoS          N/A         /media/30001663/ont.jpg
#
# [162 rows x 9 columns]
